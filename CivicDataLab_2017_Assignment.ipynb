# %% [markdown]
# ## Assignmet for the financial year 2017-2018

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
from IPython.display import display
import numpy as np

# %% [markdown]
# ### Loading the dataset

# %%
df = pd.read_csv('district_level_mapping_2017.csv', low_memory = False)

# %%
df.shape
# Out:
# (375136, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375136 entries, 0 to 375135
# Data columns (total 20 columns):
#  #   Column                                               Non-Null Count   Dtype
# ---  ------                                               --------------   -----
#  0   Division Code                                        374488 non-null  float64
#  1   Division Description                                 374488 non-null  object
#  2   Treasury Code                                        374488 non-null  float64
#  3   Treasury                                             375136 non-null  object
#  4   Grant Number                                         375136 non-null  object
#  5   Grant Head Description                               375136 non-null  object
#  6   Major Head Code                                      375136 non-null  int64
#  7   Major Head Description                               372904 non-null  object
# ...

# %%
df.sample(10)
# Out:
#         Division Code Division Description  Treasury Code     Treasury  \
# 188505         4300.0        LUCKNOW COLL.           48.0        KHERI
# 202872         1400.0            MORADABAD           92.0      SAMBHAL
# 219897         4900.0             FAIZABAD           49.0     FAIZABAD
# 92206           200.0           SAHARANPUR            2.0   SAHARANPUR
# 310662          800.0                 AGRA            8.0         AGRA
# 326347         4300.0        LUCKNOW COLL.           60.0   LUCKNOW-JB
# 50599          3300.0                BASTI           33.0        BASTI
# 249650         2300.0          JHANSI-MAIN           23.0  JHANSI-MAIN
# 331658         2700.0             VARANASI           27.0     VARANASI
# 283577          800.0                 AGRA            9.0     MAINPURI
#
#        Grant Number                             Grant Head Description  \
# 188505           49                         महिला एवं बाल कल्याण विभाग
# ...

# %%
df.isnull().sum()
# Out:
# Division Code                                           648
# Division Description                                    648
# Treasury Code                                           648
# Treasury                                                  0
# Grant Number                                              0
# Grant Head Description                                    0
# Major Head Code                                           0
# Major Head Description                                 2232
# Scheme Code                                               0
# Scheme Code Description                                   0
# Standard Object Code                                      0
# Standard Object Description                               0
# Plan / Non-Plan                                           0
# Voted / Charged                                           0
# fiscal_year                                               0
# Progressive Allotment                                     0
# ...

# %%
df['Provisional Current Month Expenditure(November)'].unique()
# Out:
# array([0])

# %%
df = df[['Grant Head Description', 'Progressive Allotment', 'Total Expenditure Upto Month (November)', '% A/E']]

# %%
df.sample(10)
# Out:
#                             Grant Head Description  Progressive Allotment  \
# 360616  संस्थागत वित्त विभाग (स्टाम्प एवं पंजीकरण)                    0.0
# 59251         कृषि तथा अन्य सम्बद्ध विभाग ((पशुधन)                30000.0
# 192028                  महिला एवं बाल कल्याण विभाग                    0.0
# 80889         कृषि तथा अन्य सम्बद्ध विभाग ((पशुधन)                25000.0
# 37761           कृषि तथा अन्य सम्बद्ध विभाग (कृषि)                    0.0
# 24939           कृषि तथा अन्य सम्बद्ध विभाग (कृषि)              1500000.0
# 246456                  महिला एवं बाल कल्याण विभाग                99000.0
# 350797                          सैनिक कल्याण विभाग                 2000.0
# 171258                                 न्याय विभाग               150000.0
# 291608    वित्त विभाग (लेखा परीक्षा, अल्प-बचत आदि)                 8000.0
#
#         Total Expenditure Upto Month (November)   % A/E
# 360616                                      0.0    0.00
# ...

# %%
# Separating primary school data from df
primary_school_df = df[df['Grant Head Description'] == 'शिक्षा विभाग (प्राथमिक शिक्षा)']

# %%
primary_school_df.shape
# Out:
# (4808, 20)

# %%
primary_school_df['Major Head Code'].unique()
# Out:
# array([2071, 2202, 2204, 4202])

# %%
primary_school_df['Major Head Description'].unique()
# Out:
# array(['पेंशन तथा अन्य सेवा निवृत्ति हित लाभ', 'सामान्य शिक्षा',
#        'खेल कूद तथा युवा सेवायें', nan], dtype=object)

# %%
primary_school_df = primary_school_df[primary_school_df['Major Head Description'] == 'सामान्य शिक्षा']

# %%
primary_school_df.shape
# Out:
# (4520, 20)

# %%
primary_school_df['Major Head Code'].unique()
# Out:
# array([2202])

# %%
pd.set_option('display.max_columns', None)
display(primary_school_df.sample(10))
# Out:
#         Division Code Division Description  Treasury Code         Treasury  \
# 301748         3200.0            GORAKHPUR           35.0           DEORIA
# 301465         5000.0                GONDA           51.0         BAHRAICH
# 299996         2800.0             MIRZAPUR           72.0          BHADOHI
# 300830         2700.0             VARANASI           27.0         VARANASI
# 301430         2700.0             VARANASI           27.0         VARANASI
# 298415         2600.0                BANDA           25.0  SADAR TRY-HMRPR
# 300337         2000.0         KANPUR NAGAR           84.0          KANNAUJ
# 300972         4300.0        LUCKNOW COLL.           60.0       LUCKNOW-JB
# 299531         4300.0        LUCKNOW COLL.           47.0           HARDOI
# 299610         2300.0          JHANSI-MAIN           58.0         LALITPUR
#
#        Grant Number          Grant Head Description  Major Head Code  \
# 301748           71  शिक्षा विभाग (प्राथमिक शिक्षा)             2202
# ...

# %%
# Separating data consisting of secondary education only
secondary_school_df = df[df['Grant Head Description'] == 'शिक्षा विभाग (माध्यमिक शिक्षा)']

# %%
secondary_school_df.shape
# Out:
# (10650, 20)

# %%
secondary_school_df['Major Head Code'].unique()
# Out:
# array([2071, 2202, 2204, 2205, 4202])

# %%
secondary_school_df['Major Head Description'].unique()
# Out:
# array(['पेंशन तथा अन्य सेवा निवृत्ति हित लाभ', 'सामान्य शिक्षा',
#        'खेल कूद तथा युवा सेवायें', 'कला एवं संस्कृति', nan], dtype=object)

# %%
secondary_school_df = secondary_school_df[secondary_school_df['Major Head Description'] == 'सामान्य शिक्षा']

# %%
secondary_school_df.shape
# Out:
# (8349, 20)

# %%
secondary_school_df['Major Head Code'].unique()
# Out:
# array([2202])

# %%
secondary_school_df.sample(10)
# Out:
#         Division Code Division Description  Treasury Code         Treasury  \
# 306787         2000.0         KANPUR NAGAR           62.0     KANPUR DEHAT
# 307664          400.0         MEERUT SADAR            4.0     MEERUT SADAR
# 303370         3300.0                BASTI           67.0  SIDDHARTH NAGAR
# 309315         3300.0                BASTI           33.0            BASTI
# 307625          400.0         MEERUT SADAR            4.0     MEERUT SADAR
# 307773         1400.0            MORADABAD           14.0        MORADABAD
# 308524          200.0           SAHARANPUR           91.0           SHAMLI
# 303938          400.0         MEERUT SADAR            4.0     MEERUT SADAR
# 308021         2200.0            ALLAHABAD           53.0       PRATAPGARH
# 305591          800.0                 AGRA           10.0             ETAH
#
#        Grant Number          Grant Head Description  Major Head Code  \
# 306787           72  शिक्षा विभाग (माध्यमिक शिक्षा)             2202
# ...

# %%
# concatening primary and secondary school education to get our required dataframe
school_df = pd.concat([primary_school_df, secondary_school_df])

# %%
school_df.shape
# Out:
# (12869, 20)

# %%
school_df['Major Head Description'].unique()
# Out:
# array(['सामान्य शिक्षा'], dtype=object)

# %%
# Required data frame
school_df.sample(10)
# Out:
#         Division Code Division Description  Treasury Code         Treasury  \
# 303579          400.0         MEERUT SADAR            4.0     MEERUT SADAR
# 306320         3200.0            GORAKHPUR           32.0        GORAKHPUR
# 305458         4300.0        LUCKNOW COLL.           89.0  CSMAHARAJ NAGAR
# 298839         3400.0             AZAMGARH           66.0              MAU
# 305871         2200.0            ALLAHABAD           21.0         FATEHPUR
# 298981         3200.0            GORAKHPUR           70.0      MAHARAJGANJ
# 304239         4900.0             FAIZABAD           74.0    AMBEDKARNAGAR
# 304558         5000.0                GONDA           51.0         BAHRAICH
# 304537          400.0         MEERUT SADAR           83.0    BAGHPAT SADAR
# 310504         4300.0        LUCKNOW COLL.           60.0       LUCKNOW-JB
#
#        Grant Number          Grant Head Description  Major Head Code  \
# 303579           72  शिक्षा विभाग (माध्यमिक शिक्षा)             2202
# ...

# %%
# taking only those columns which are needed
school_df.isnull().sum()
# Out:
# Division Code                                          0
# Division Description                                   0
# Treasury Code                                          0
# Treasury                                               0
# Grant Number                                           0
# Grant Head Description                                 0
# Major Head Code                                        0
# Major Head Description                                 0
# Scheme Code                                            0
# Scheme Code Description                                0
# Standard Object Code                                   0
# Standard Object Description                            0
# Plan / Non-Plan                                        0
# Voted / Charged                                        0
# fiscal_year                                            0
# Progressive Allotment                                  0
# ...

# %%
school_df['Provisional Current Month Expenditure(November)'].unique()
# Out:
# array([0])

# %%
# taking only those columns which are needed from df
school_df = school_df[['Grant Head Description', 'Progressive Allotment', 'Total Expenditure Upto Month (November)', '% A/E']]

# %%
school_df.sample(10)
# Out:
#                 Grant Head Description  Progressive Allotment  \
# 303149  शिक्षा विभाग (माध्यमिक शिक्षा)                70000.0
# 310544  शिक्षा विभाग (माध्यमिक शिक्षा)             10300000.0
# 309979  शिक्षा विभाग (माध्यमिक शिक्षा)               168088.0
# 306538  शिक्षा विभाग (माध्यमिक शिक्षा)               900000.0
# 302937  शिक्षा विभाग (माध्यमिक शिक्षा)                    0.0
# 309847  शिक्षा विभाग (माध्यमिक शिक्षा)                    0.0
# 301020  शिक्षा विभाग (प्राथमिक शिक्षा)                18600.0
# 308172  शिक्षा विभाग (माध्यमिक शिक्षा)             12500000.0
# 308560  शिक्षा विभाग (माध्यमिक शिक्षा)                    0.0
# 299915  शिक्षा विभाग (प्राथमिक शिक्षा)                 1500.0
#
#         Total Expenditure Upto Month (November)   % A/E
# 303149                                  48040.0   68.63
# 310544                                6951680.0   67.49
# 309979                                 168088.0  100.00
# 306538                                 510447.0   56.72
# ...

# %%
school_df.shape
# Out:
# (12869, 4)

# %%
df.shape
# Out:
# (375136, 4)

# %% [markdown]
# ### 1.Calculate the share of expenditure on school education incurred by various departments/ministries.

# %%
#this will be calculated division of (sum of progressive allotme)
df['Progressive Allotment'] = df.sum(axis = 1)
# Out:
# <ipython-input-68-ab848a3214cb>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['Progressive Allotment'] = df.sum(axis = 1)
